# %%
pip install bs4

# %%
pip install requests

# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib.parse
import pandas as pd

job_name=input('Enter job name: ')
parse_job_name=urllib.parse.quote(job_name)

job_country=input('Enter job country: ')

url=f'https://www.linkedin.com/jobs/search?keywords={parse_job_name}&location=egypt&geoId=106155005&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0'
Job_titles, companies,companies_link, locations, links, Experience_Needed,publish_time =[], [], [], [], [], [], []

response=requests.get(url)
soup=bs(response.content, 'html.parser')
soup

# %%
containers = soup.find_all("div", class_="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card")
len(containers)
# Out:
# 55

# %%
for container in containers:
  job_title = container.find("h3", class_="base-search-card__title")
  Job_titles.append(job_title.text.strip())

  company = container.find("h4", class_="base-search-card__subtitle")
  companies.append(company.text.strip())

  company_link=container.find("a", class_="hidden-nested-link")
  companies_link.append(company_link.get('href'))

  location = container.find("span", class_="job-search-card__location")
  locations.append(location.text.strip())

  time = container.find("time")
  print(time.text.strip())
  publish_time.append(time.text.strip())


  link = container.find("a", class_="base-card__full-link")
  links.append(link.get('href'))
# Out:
# 1 month ago
# 4 days ago
# 3 weeks ago
# 2 months ago
# 2 days ago
# 4 months ago
# 3 weeks ago
# 1 month ago
# 1 day ago
# 1 day ago
# 2 weeks ago
# 2 weeks ago
# 2 months ago
# 2 months ago
# 4 months ago
# 1 month ago
# 2 weeks ago
# 1 day ago
# 1 week ago
# 1 day ago
# 3 days ago
# 1 week ago
# 1 week ago
# 5 days ago
# 5 days ago
# 1 week ago
# 2 months ago
# 1 month ago
# 1 day ago
# 11 hours ago
# 2 weeks ago
# 6 hours ago
# 4 days ago
# 2 weeks ago
# 1 day ago
# 2 days ago
# 1 month ago
# 1 day ago
# 2 weeks ago
# 3 days ago
# 1 week ago
# 2 weeks ago
# 1 week ago
# 1 week ago
# 2 days ago
# 3 weeks ago
# 1 week ago
# 1 day ago
# 1 month ago
# 1 week ago
# 3 days ago
# 1 week ago
# 3 days ago
# 1 month ago
# 1 day ago

# %%
df=pd.DataFrame({'Job Title':Job_titles,'Company':companies,'company link':companies_link,'Location':locations,'Publish Time':publish_time,'link':links})
df
# Out:
#                                           Job Title  \
# 0                                  Business Analyst
# 1                        Odoo Functional Consultant
# 2                                    Odoo Developer
# 3                                    Odoo Developer
# 4              Projects Delivery Manager (Odoo ERP)
# 5                                 Junior Accountant
# 6        Information Technology Project Coordinator
# 7                                   ERP Lead - Odoo
# 8                                    ODOO Developer
# 9                                   odoo consultant
# 10                                 Business Analyst
# 11                               ERPNext consultant
# 12  Tech Innovation - R&D Software Engineer - Cairo
# 13  Tech Innovation - R&D Software Engineer - Cairo
# 14                             Supply Chain Manager
# 15                         Senior Odoo Implementors
# 16            Odoo Expert / Implementer / Developer
# ...

# %%
df.to_csv(f'jobs_{job_name}.csv', index=False)

# %%
https://www.linkedin.com/jobs/search?keywords=data%20analyist&location=%D9%85%D8%B5%D8%B1&geoId=106155005&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0
